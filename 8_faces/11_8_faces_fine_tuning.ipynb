# %% [markdown]
# ## 8 faces fine tuning
# In this nootebook we want to do some transfer learning to get a better classification performance on the data set with the 8 celebreties. For this we use a pretrained vgg16 network. We push each image through the trained VGG16 net and fetch the entries in the fc1 layer which we will use as CNN-feature representation of the respective image. The fetching of these CNN features is already done in another notbook (since loading of VGG16 including the top layer requires some time and space). Here we load '8_faces_EMB.npz' containing the CNN feature representation which were obtained by a pretrained VGG16. Then we train a fully connected network with these CNN-features and our own labels - this is called transfer learning since the feature extractor was learned on another data set (1 million images from iamgeNet with 1000 class labels).

# %%
import gzip
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as imgplot
import time
# %matplotlib inline
import h5py
from scipy import misc
import os
import random

# %% [markdown]
# Load the dataset that contains the CNN-feature representation of the 8-faces data set (because of computational reasons we just load them)

# %%
# Downloading the data, if it does not exist
import urllib
import os
if not os.path.isfile('8_faces_EMB.npz'):
    urllib.request.urlretrieve(
    "https://www.dropbox.com/s/3w3x9i7ng7017l3/8_faces_EMB.npz?dl=1",
    "8_faces_EMB.npz")
# %ls -hl 8_faces_EMB.npz
# Out:
#  Datenträger in Laufwerk D: ist Data
#  Volumeseriennummer: AAE6-0763
#
#  Verzeichnis von D:\ZHAW\CAS_Machine_Intelligence\M2_DeepLearning\8_faces_challenge
#
#
#  Verzeichnis von D:\ZHAW\CAS_Machine_Intelligence\M2_DeepLearning\8_faces_challenge
#
# 20.03.2018  11:28        49 863 217 8_faces_EMB.npz
#                1 Datei(en),     49 863 217 Bytes
#                0 Verzeichnis(se), 596 438 532 096 Bytes frei

# %%
Data=np.load("8_faces_EMB.npz")
print(Data.files)
X_train = Data["arr_0"]
X_valid = Data["arr_1"]
X_test =  Data["arr_2"]
Y_train = Data["arr_3"]
Y_valid = Data["arr_4"]
Y_test =  Data["arr_5"]
print(X_train.shape)
print(X_valid.shape)
print(Y_train.shape)
print(Y_valid.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# ['arr_1', 'arr_0', 'arr_3', 'arr_2', 'arr_5', 'arr_4']
# (2000, 4096)
# (400, 4096)
# (2000,)
# (400,)
# (400, 4096)
# (400,)

# %%
def convertToOneHot(vector, num_classes=None):
    result = np.zeros((len(vector), num_classes), dtype='int32')
    result[np.arange(len(vector)), vector] = 1
    return result

# %%
Y_train=convertToOneHot(Y_train,num_classes=8)
Y_valid=convertToOneHot(Y_valid,num_classes=8)

# %%
import keras
from keras.layers import Dense, Activation, Dropout, BatchNormalization
from keras.models import Sequential
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Define the network

# %%
model = Sequential()
name = '8_faces_finetune'

model.add(Dense(400, batch_input_shape=((None, 4096))))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(0.3))

model.add(Dense(400))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(0.3))

model.add(Dense(200))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(0.5))

model.add(Dense(8))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 400)               1638800
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 400)               1600
# _________________________________________________________________
# activation_1 (Activation)    (None, 400)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 400)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 400)               160400
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 400)               1600
# _________________________________________________________________
# activation_2 (Activation)    (None, 400)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 400)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 200)               80200
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 200)               800
# _________________________________________________________________
# activation_3 (Activation)    (None, 200)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 1608
# _________________________________________________________________
# activation_4 (Activation)    (None, 8)                 0
# =================================================================
# Total params: 1,885,008
# Trainable params: 1,883,008
# Non-trainable params: 2,000
# _________________________________________________________________

# %%
tensorboard = keras.callbacks.TensorBoard(
        log_dir='tensorboard/8_faces/' + name + '/', 
        write_graph=True,
        histogram_freq=1)

# %%
os.makedirs("Checkpoints/8_faces/model_vgg_finetuning/",exist_ok=True)       
checkpointer = keras.callbacks.ModelCheckpoint( 
        filepath =  "Checkpoints/8_faces/model_vgg_finetuning/8_faces_cnn_"+"weights_epoch_{epoch:03d}-{val_loss:.2f}.hdf5",
        verbose = 1, 
        save_best_only = False,
        period = 10 )

# %% [markdown]
# #### Training the network

# %%
history=model.fit(X_train, Y_train, 
                  batch_size=128, 
                  epochs=30,
                  verbose=2, 
                  validation_data=(X_valid, Y_valid),
                  callbacks=[tensorboard, checkpointer])
# Out:
# Train on 2000 samples, validate on 400 samples
# Epoch 1/30
#  - 1s - loss: 2.0042 - acc: 0.3275 - val_loss: 1.2955 - val_acc: 0.5425
# Epoch 2/30
#  - 1s - loss: 1.2746 - acc: 0.5355 - val_loss: 1.0792 - val_acc: 0.6125
# Epoch 3/30
#  - 1s - loss: 0.9524 - acc: 0.6595 - val_loss: 0.9250 - val_acc: 0.6500
# Epoch 4/30
#  - 1s - loss: 0.8547 - acc: 0.6950 - val_loss: 0.8966 - val_acc: 0.6850
# Epoch 5/30
#  - 1s - loss: 0.7110 - acc: 0.7545 - val_loss: 0.7800 - val_acc: 0.7375
# Epoch 6/30
#  - 1s - loss: 0.5834 - acc: 0.8030 - val_loss: 0.7921 - val_acc: 0.7375
# Epoch 7/30
#  - 1s - loss: 0.4878 - acc: 0.8355 - val_loss: 0.7667 - val_acc: 0.7300
# Epoch 8/30
#  - 1s - loss: 0.4063 - acc: 0.8645 - val_loss: 0.8248 - val_acc: 0.7425
# Epoch 9/30
#  - 1s - loss: 0.3561 - acc: 0.8825 - val_loss: 0.7540 - val_acc: 0.7900
# Epoch 10/30
#  - 1s - loss: 0.2775 - acc: 0.9120 - val_loss: 0.6713 - val_acc: 0.7800
#
# Epoch 00010: saving model to Checkpoints/8_faces/model_vgg_finetuning/8_faces_cnn_weights_epoch_010-0.67.hdf5
# Epoch 11/30
#  - 1s - loss: 0.2527 - acc: 0.9235 - val_loss: 0.7464 - val_acc: 0.7525
# Epoch 12/30
#  - 1s - loss: 0.2099 - acc: 0.9430 - val_loss: 0.7879 - val_acc: 0.7775
# Epoch 13/30
#  - 1s - loss: 0.1948 - acc: 0.9385 - val_loss: 0.7739 - val_acc: 0.7600
# Epoch 14/30
#  - 1s - loss: 0.1589 - acc: 0.9525 - val_loss: 0.7777 - val_acc: 0.7475
# Epoch 15/30
#  - 1s - loss: 0.1524 - acc: 0.9560 - val_loss: 0.7942 - val_acc: 0.7675
# Epoch 16/30
#  - 1s - loss: 0.1372 - acc: 0.9575 - val_loss: 0.7979 - val_acc: 0.7900
# Epoch 17/30
#  - 1s - loss: 0.1185 - acc: 0.9690 - val_loss: 0.7585 - val_acc: 0.7750
# Epoch 18/30
#  - 1s - loss: 0.1055 - acc: 0.9710 - val_loss: 0.9587 - val_acc: 0.7175
# Epoch 19/30
#  - 1s - loss: 0.0933 - acc: 0.9770 - val_loss: 0.7457 - val_acc: 0.7875
# Epoch 20/30
#  - 1s - loss: 0.0979 - acc: 0.9700 - val_loss: 0.7659 - val_acc: 0.7750
#
# Epoch 00020: saving model to Checkpoints/8_faces/model_vgg_finetuning/8_faces_cnn_weights_epoch_020-0.77.hdf5
# Epoch 21/30
#  - 1s - loss: 0.0898 - acc: 0.9715 - val_loss: 1.1674 - val_acc: 0.7100
# Epoch 22/30
#  - 1s - loss: 0.0793 - acc: 0.9750 - val_loss: 0.8969 - val_acc: 0.7900
# Epoch 23/30
#  - 1s - loss: 0.0738 - acc: 0.9755 - val_loss: 0.9038 - val_acc: 0.7600
# Epoch 24/30
#  - 1s - loss: 0.0764 - acc: 0.9785 - val_loss: 1.0101 - val_acc: 0.7400
# Epoch 25/30
#  - 1s - loss: 0.0682 - acc: 0.9840 - val_loss: 0.9025 - val_acc: 0.7550
# Epoch 26/30
#  - 1s - loss: 0.0801 - acc: 0.9775 - val_loss: 0.8744 - val_acc: 0.7650
# Epoch 27/30
#  - 1s - loss: 0.0689 - acc: 0.9805 - val_loss: 1.0515 - val_acc: 0.7725
# Epoch 28/30
#  - 1s - loss: 0.0622 - acc: 0.9840 - val_loss: 0.9279 - val_acc: 0.7650
# Epoch 29/30
#  - 1s - loss: 0.0548 - acc: 0.9830 - val_loss: 0.9184 - val_acc: 0.7725
# Epoch 30/30
#  - 1s - loss: 0.0492 - acc: 0.9875 - val_loss: 0.8886 - val_acc: 0.7800
#
# Epoch 00030: saving model to Checkpoints/8_faces/model_vgg_finetuning/8_faces_cnn_weights_epoch_030-0.89.hdf5

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train acc', 'test acc'], loc='lower right')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'test loss'], loc='upper right')
plt.show()

# %% [markdown]
# #### Evaluation of the trained network

# %%
# your code, get the probabilities for each image of the test set 
preds_test_classes = model.predict_classes(X_test)
preds_test=model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(Y_test, preds_test_classes))
print("Acc = " , np.sum(Y_test == preds_test_classes) / len(Y_test))
# Out:
# [[39  2  2  2  0  1  4  0]
#  [ 0 33  0  8  2  5  1  1]
#  [ 1  0 47  0  0  1  0  1]
#  [ 0  0  0 48  0  1  1  0]
#  [ 0  2  0  1 44  1  2  0]
#  [ 0  1  1  4  0 43  1  0]
#  [ 4  1  1  5  0  3 35  1]
#  [ 0  2  6  1  2  1  2 36]]
# Acc =  0.8125

# %%
# Downloading the data, if it does not exist
if not os.path.isfile('8_faces_test.hdf5'):
    urllib.request.urlretrieve(
    "https://www.dropbox.com/s/ugxrdo0lpc2ixvr/8_faces_test.hdf5?dl=1",
    "8_faces_test.hdf5")

# %%
h5f_X = h5py.File('8_faces_test.hdf5', 'r')
print(list(h5f_X.keys()))
X_test = h5f_X['X_test_8_faces']
print(X_test.shape)
Y_test = h5f_X['Y_test_8_faces']
print(Y_test.shape)
# Out:
# ['X_test_8_faces', 'Y_test_8_faces']
# (400, 48, 48, 3)
# (400,)

# %% [markdown]
# #### Visualize right and wrong classified images

# %%
pred=np.argmax(preds_test,axis=1)
Klasse=1
right = np.where(Y_test[:]==Klasse)[0][np.where(np.in1d(np.where(Y_test[:]==Klasse),np.where(pred[:]==Klasse)))]
wrong = np.where(Y_test[:]==Klasse)[0][(np.in1d(np.where(Y_test[:]==Klasse),np.where(pred[:]==Klasse)))==False]

plt.figure(figsize=(18,18))
for i in range(0,len(right)):
    plt.subplot(10,10,(i+1))
    plt.imshow(np.asarray(X_test[right[i]],dtype="uint8"))
    plt.axis('off')
    plt.title('right')
    
plt.figure(figsize=(18,18))
for i in range(0,len(wrong)):
    plt.subplot(10,10,(i+1))
    plt.imshow(np.asarray(X_test[wrong[i]],dtype="uint8"))
    plt.axis('off')
    plt.title('wrong')
